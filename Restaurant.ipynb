# %% [markdown]
# ### Loading the Standard Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('zomato.csv',encoding= 'latin1')
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### Total columns present in the data

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# ### Total rows and columns in the data

# %%
data.shape
# Out:
# (9551, 21)

# %% [markdown]
# #### Observation:
#          - Total numof rows 9551 and 21 columns in the data

# %% [markdown]
# ### Deleting unnecessary columns in the data

# %%
col_to_del = ['Country Code', 'Address','Locality', 'Locality Verbose','Longitude', 'Latitude','Switch to order menu', 'Rating color']
col_to_del
# Out:
# ['Country Code',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Switch to order menu',
#  'Rating color']

# %%
updated_data = data.drop(col_to_del,axis = 1)
updated_data
# Out:
#       Restaurant ID           Restaurant Name              City  \
# 0           6317637          Le Petit Souffle       Makati City
# 1           6304287          Izakaya Kikufuji       Makati City
# 2           6300002    Heat - Edsa Shangri-La  Mandaluyong City
# 3           6318506                      Ooma  Mandaluyong City
# 4           6314302               Sambo Kojin  Mandaluyong City
# ...             ...                       ...               ...
# 9546        5915730              NamlÛ± Gurme         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548        5915807                     Huqqa         ÛÁstanbul
# 9549        5916112              Aôôk Kahve         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery         ÛÁstanbul
#
#                               Cuisines  Average Cost for two  \
# 0           French, Japanese, Desserts                  1100
# 1                             Japanese                  1200
# ...

# %%
updated_data.head()
# Out:
#    Restaurant ID         Restaurant Name              City  \
# 0        6317637        Le Petit Souffle       Makati City
# 1        6304287        Izakaya Kikufuji       Makati City
# 2        6300002  Heat - Edsa Shangri-La  Mandaluyong City
# 3        6318506                    Ooma  Mandaluyong City
# 4        6314302             Sambo Kojin  Mandaluyong City
#
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
# 3                   Japanese, Sushi                  1500  Botswana Pula(P)
# 4                  Japanese, Korean                  1500  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  Price range  \
# 0               Yes                  No                No            3
# ...

# %%
updated_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'City', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating text', 'Votes'],
#       dtype='object')

# %%
updated_data.shape
# Out:
# (9551, 13)

# %% [markdown]
# ### Proportion of Excellent rating of restuarent

# %%
data['Rating text'].value_counts(normalize = True) * 100
# Out:
# Average      39.126793
# Not rated    22.489792
# Good         21.987226
# Very Good    11.297246
# Excellent     3.151502
# Poor          1.947440
# Name: Rating text, dtype: float64

# %%
updated_data[updated_data['Rating text'] == 'Excellent']
# Out:
#       Restaurant ID                           Restaurant Name  \
# 0           6317637                          Le Petit Souffle
# 1           6304287                          Izakaya Kikufuji
# 3           6318506                                      Ooma
# 4           6314302                               Sambo Kojin
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila
# ...             ...                                       ...
# 9537        5904116                       J'adore Chocolatier
# 9538        5901782                                 Starbucks
# 9540        5927248                          Draft Gastro Pub
# 9543        5916085                              Dem Karakí_y
# 9544        5915547                     Karakí_y Gí_llí_oÛôlu
#
#                   City                    Cuisines  Average Cost for two  \
# 0          Makati City  French, Japanese, Desserts                  1100
# ...

# %% [markdown]
# ### Observation:
# - There is 39% of average ratings for the restaurants
# - there is only 3% of restaurants having ratings Excellent
# -11 % of restaurants having very good rating

# %% [markdown]
# ### Total count of restuarants having aggregate rating greater than or equal to 4

# %%
 updated_data[updated_data[ 'Aggregate rating'] >= 4]['Restaurant Name'].count()
# Out:
# 1380

# %% [markdown]
# ### Analyzing city variable

# %%
updated_data['City'].value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %% [markdown]
# ### Proportion of Text Ratings in New Delhi

# %%
updated_data[updated_data['City'] == 'New Delhi']['Rating text'].value_counts(normalize = True) * 100 # percentage
# Out:
# Average      45.587429
# Not rated    26.036908
# Good         20.610269
# Very Good     5.481454
# Poor          1.772337
# Excellent     0.511602
# Name: Rating text, dtype: float64

# %% [markdown]
# ### Count of restuarents in New Delhi with aggregate rating >=4

# %%
updated_data[(updated_data['City'] == 'New Delhi') & (updated_data['Aggregate rating'] >=4)]['Restaurant Name'].count()
# Out:
# 328

# %%
updated_data[['Restaurant Name','Cuisines']]
# Out:
#                Restaurant Name                          Cuisines
# 0             Le Petit Souffle        French, Japanese, Desserts
# 1             Izakaya Kikufuji                          Japanese
# 2       Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3                         Ooma                   Japanese, Sushi
# 4                  Sambo Kojin                  Japanese, Korean
# ...                        ...                               ...
# 9546              NamlÛ± Gurme                           Turkish
# 9547             Ceviz AÛôacÛ±   World Cuisine, Patisserie, Cafe
# 9548                     Huqqa            Italian, World Cuisine
# 9549              Aôôk Kahve                   Restaurant Cafe
# 9550  Walter's Coffee Roastery                              Cafe
#
# [9551 rows x 2 columns]

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
col_del= ['Country Code', 'Address','Locality', 'Locality Verbose','Longitude', 'Latitude','Switch to order menu', 'Rating color']
col_del
# Out:
# ['Country Code',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Switch to order menu',
#  'Rating color']

# %%
data1 = data.drop(col_del,axis = 1)
data1
# Out:
#       Restaurant ID           Restaurant Name              City  \
# 0           6317637          Le Petit Souffle       Makati City
# 1           6304287          Izakaya Kikufuji       Makati City
# 2           6300002    Heat - Edsa Shangri-La  Mandaluyong City
# 3           6318506                      Ooma  Mandaluyong City
# 4           6314302               Sambo Kojin  Mandaluyong City
# ...             ...                       ...               ...
# 9546        5915730              NamlÛ± Gurme         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548        5915807                     Huqqa         ÛÁstanbul
# 9549        5916112              Aôôk Kahve         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery         ÛÁstanbul
#
#                               Cuisines  Average Cost for two  \
# 0           French, Japanese, Desserts                  1100
# 1                             Japanese                  1200
# ...

# %%
data1['Currency'].value_counts()
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %%
zomato_india1 = data1[data1['Currency'] == 'Indian Rupees(Rs.)']
zomato_india1
# Out:
#       Restaurant ID                        Restaurant Name   City  \
# 624         3400025                             Jahanpanah   Agra
# 625         3400341                    Rangrezz Restaurant   Agra
# 626         3400005                Time2Eat - Mama Chicken   Agra
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya   Agra
# 628         3400017                         Pinch Of Spice   Agra
# ...             ...                                    ...    ...
# 9271        2800100                               D Cabana  Vizag
# 9272        2800418                               Kaloreez  Vizag
# 9273        2800881                                Plot 17  Vizag
# 9274        2800042                       Vista - The Park  Vizag
# 9275        2800019               Flying Spaghetti Monster  Vizag
#
#                                                Cuisines  Average Cost for two  \
# 624                               North Indian, Mughlai                   850
# ...

# %% [markdown]
# ## Total count of Cuisines in the Indian Restuarants

# %%
zomato_india1['Cuisines'].unique()
# Out:
# array(['North Indian, Mughlai', 'North Indian', 'Rajasthani', ...,
#        'Continental, Seafood, Chinese, North Indian, Biryani',
#        'Burger, Pizza, Biryani',
#        'American, North Indian, Thai, Continental'], dtype=object)

# %%
zomato_india1['Cuisines'].count()
# Out:
# 8652

# %% [markdown]
# ## How Many restaurants have online delivery

# %%
zomato_india1.groupby('Has Online delivery').agg('count')
# Out:
#                      Restaurant ID  Restaurant Name  City  Cuisines  \
# Has Online delivery
# No                            6229             6229  6229      6229
# Yes                           2423             2423  2423      2423
#
#                      Average Cost for two  Currency  Has Table booking  \
# Has Online delivery
# No                                   6229      6229               6229
# Yes                                  2423      2423               2423
#
#                      Is delivering now  Price range  Aggregate rating  \
# Has Online delivery
# No                                6229         6229              6229
# Yes                               2423         2423              2423
#
#                      Rating text  Votes
# Has Online delivery
# No                          6229   6229
# Yes                         2423   2423

# %%
zomato_india1.groupby('Has Online delivery')['Restaurant Name'].agg('count')
# Out:
# Has Online delivery
# No     6229
# Yes    2423
# Name: Restaurant Name, dtype: int64

# %%
zomato_india1.groupby('Has Online delivery')['Restaurant Name'].agg('count') / len(zomato_india) * 100 # percentage
# Out:
# Has Online delivery
# No     71.994914
# Yes    28.005086
# Name: Restaurant Name, dtype: float64

# %%
zomato_india1['City'].unique()
# Out:
# array(['Agra', 'Ahmedabad', 'Allahabad', 'Amritsar', 'Aurangabad',
#        'Bangalore', 'Bhopal', 'Bhubaneshwar', 'Chandigarh', 'Chennai',
#        'Coimbatore', 'Dehradun', 'Faridabad', 'Ghaziabad', 'Goa',
#        'Gurgaon', 'Guwahati', 'Hyderabad', 'Indore', 'Jaipur', 'Kanpur',
#        'Kochi', 'Kolkata', 'Lucknow', 'Ludhiana', 'Mangalore', 'Mohali',
#        'Mumbai', 'Mysore', 'Nagpur', 'Nashik', 'New Delhi', 'Noida',
#        'Panchkula', 'Patna', 'Puducherry', 'Pune', 'Ranchi',
#        'Secunderabad', 'Surat', 'Vadodara', 'Varanasi', 'Vizag'],
#       dtype=object)

# %% [markdown]
# ## Maximum cost for two per city

# %%
zomato_india1.groupby('City')[['Restaurant Name','Average Cost for two']].agg('max')
# Out:
#                              Restaurant Name  Average Cost for two
# City
# Agra                 Time2Eat - Mama Chicken                  3600
# Ahmedabad                     Yanki Sizzlers                  1800
# Allahabad                  The Tamarind Tree                  1000
# Amritsar                   The Yellow Chilli                  1200
# Aurangabad                    d' Curry House                  1800
# Bangalore                           Truffles                  2400
# Bhopal                           Violet Hour                  1800
# Bhubaneshwar                      Tyre Patty                  1500
# Chandigarh                  Virgin Courtyard                  2200
# Chennai                        Writer's Cafe                  2000
# Coimbatore                    Zucca Pizzeria                  1500
# Dehradun                 Y Cafe & Restaurant                  1600
# Faridabad                         Yummy Cake                  1900
# ...

# %%
zomato_india1.groupby('City')[['Restaurant Name','Average Cost for two']].agg(['max','min'])
# Out:
#                              Restaurant Name  \
#                                          max
# City
# Agra                 Time2Eat - Mama Chicken
# Ahmedabad                     Yanki Sizzlers
# Allahabad                  The Tamarind Tree
# Amritsar                   The Yellow Chilli
# Aurangabad                    d' Curry House
# Bangalore                           Truffles
# Bhopal                           Violet Hour
# Bhubaneshwar                      Tyre Patty
# Chandigarh                  Virgin Courtyard
# Chennai                        Writer's Cafe
# Coimbatore                    Zucca Pizzeria
# Dehradun                 Y Cafe & Restaurant
# Faridabad                         Yummy Cake
# Ghaziabad                      The Dosa King
# Goa                    The Fisherman's Wharf
# Gurgaon                             iKitchen
# Guwahati                                Ziya
# Hyderabad           United Kitchens of India
# Indore                          Waffle House
# ...

# %%
zomato_india[zomato_india['Average Cost for two'] >= 8000]
# Out:
#       Restaurant ID                    Restaurant Name       City Cuisines  \
# 7543           2701  Orient Express - Taj Palace Hotel  New Delhi      nan
#
#       Average Cost for two            Currency Has Table booking  \
# 7543                  8000  Indian Rupees(Rs.)               Yes
#
#      Has Online delivery Is delivering now  Price range  Aggregate rating  \
# 7543                  No                No            4               4.0
#
#      Rating text  Votes
# 7543   Very Good    145
